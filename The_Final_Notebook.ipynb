# %% [markdown]
# # **Welcome to the notebook**

# %% [markdown]
# ### Task 1 - Set up project environment

# %% [markdown]
# Installing the needed modules

# %%
# !pip install openai==1.16.2 python-dotenv
# Out:
# Collecting openai==1.16.2
#   Downloading openai-1.16.2-py3-none-any.whl.metadata (21 kB)
# Collecting python-dotenv
#   Downloading python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai==1.16.2) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai==1.16.2) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai==1.16.2) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from openai==1.16.2) (2.11.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai==1.16.2) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.11/dist-packages (from openai==1.16.2) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.11/dist-packages (from openai==1.16.2) (4.14.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->openai==1.16.2) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai==1.16.2) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai==1.16.2) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai==1.16.2) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai==1.16.2) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai==1.16.2) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai==1.16.2) (0.4.1)
# Downloading openai-1.16.2-py3-none-any.whl (267 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.1/267.1 kB 9.7 MB/s eta 0:00:00
# Downloading python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Installing collected packages: python-dotenv, openai
#   Attempting uninstall: openai
#     Found existing installation: openai 1.97.0
#     Uninstalling openai-1.97.0:
#       Successfully uninstalled openai-1.97.0
# Successfully installed openai-1.16.2 python-dotenv-1.1.1

# %%
    pip install httpx==0.27.2
# Out:
# Collecting httpx==0.27.2
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx==0.27.2) (4.9.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx==0.27.2) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx==0.27.2) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx==0.27.2) (3.10)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from httpx==0.27.2) (1.3.1)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx==0.27.2) (0.16.0)
# Requirement already satisfied: typing_extensions>=4.5 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx==0.27.2) (4.14.1)
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 4.3 MB/s eta 0:00:00
# Installing collected packages: httpx
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.28.1
#     Uninstalling httpx-0.28.1:
#       Successfully uninstalled httpx-0.28.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-genai 1.26.0 requires httpx<1.0.0,>=0.28.1, but you have httpx 0.27.2 which is incompatible.
# firebase-admin 6.9.0 requires httpx[http2]==0.28.1, but you have httpx 0.27.2 which is incompatible.
# Successfully installed httpx-0.27.2

# %% [markdown]
# Importing the needed modules and setup the OpenAI API

# %%
import pandas as pd
import numpy as np
import os
from openai import OpenAI
from dotenv import load_dotenv
from matplotlib import pyplot as plt
import plotly.express as px

from sklearn.decomposition import PCA
from sklearn.metrics.pairwise import cosine_similarity

# Loading API key and organization ID from a dotenv file
load_dotenv(dotenv_path='apikey.env.txt')

# Retrieving API key and organization ID from environment variables
APIKEY = os.getenv("APIKEY")
APIKEY = 'APIKEY'
# ORGID = os.getenv("ORGID")

# Creating an instance of the OpenAI client with the provided API key and organization ID
client = OpenAI(
  # organization= ORGID,
  api_key=APIKEY
)

client

# %% [markdown]
# Import our dataset

# %%
df = pd.read_csv('products_dataset.csv')
df
# Out:
#      product_id                                              title  \
# 0            P0  Men's 3X Large Carbon Heather Cotton/Polyester...
# 1            P1  Turmode 30 ft. RP TNC Female to RP TNC Male Ad...
# 2            P2                         Large Tapestry Bolster Bed
# 3            P3    16-Gauge-Sinks Vessel Sink in White with Faucet
# 4            P4  Men's Crazy Horse 9'' Logger Boot - Steel Toe ...
# ...         ...                                                ...
# 1995      P1995  Dotty Black and White Black and White Wallpape...
# 1996      P1996  Abrielle Brown/Light Gray 8 ft. x 10 ft. Orien...
# 1997      P1997  20 in. x 2-1/2 in. x 2-1/2 in. Polyurethane As...
# 1998      P1998  1 gal. #P120-6 Diva Glam Flat Exterior Paint &...
# 1999      P1999  Amsterdam Ivory/Terracotta 2 ft. x 8 ft. Geome...
#
#                                             description
# 0     This heavyweight, water-repellent hooded sweat...
# 1     If you need more length between your existing ...
# 2     Polyester cover resembling rich Italian tapest...
# 3     It features a rectangle shape. This vessel set...
# 4     This 9 in. black full grain leather logger boo...
# ...                                                 ...
# 1995  With a stylish monochrome look, this dotty wal...
# 1996  The Abrielle collection features a stunning as...
# 1997  With Fypon balustrade systems, you can transfo...
# 1998  BEHR PREMIUM PLUS Exterior Paint & Primer is a...
# 1999  A refreshing take on innovative designs, Safav...
#
# [2000 rows x 3 columns]

# %% [markdown]
# List of last 8 products recently viewed by the user.

# %%
searched_products_id = [
    'P1938',
    'P1970',
    'P1044',
    'P1838',
    'P1048',
    'P1017',
    'P1310',
    'P1444',
]

# %% [markdown]
# ### Task 2 - Prepare the dataset

# %% [markdown]
# Let's label the data points that are recently veiwed.

# %%
df['product_status'] = 'not_viewed'
df.loc[df.product_id.isin(searched_products_id),'product_status'] = 'recently_viewed'
df[df.product_status=='recently_viewed']
# Out:
#      product_id                                              title  \
# 1017      P1017  1 qt. #660D-7 Blackberry Farm Satin Enamel Int...
# 1044      P1044  1 qt. #M360-4 Marjoram One-Coat Hide Eggshell ...
# 1048      P1048  5 gal. #640C-1 Hosta Flower Extra Durable Sati...
# 1310      P1310  5 gal. #180A-2 Romantic Morn Extra Durable Sem...
# 1444      P1444  5 gal. #PPU12-17 Cameroon Green Extra Durable ...
# 1838      P1838  5 gal. #N340-2 Dune Grass Extra Durable Satin ...
# 1938      P1938  1 gal. #HDC-SP16-10 Japanese Rose Garden Semi-...
# 1970      P1970  8 oz. #510C-3 Rivers Edge Semi-Gloss Enamel St...
#
#                                             description   product_status
# 1017  Love your space like never before with the hig...  recently_viewed
# 1044  Introducing the best of BEHR Paint. Featuring ...  recently_viewed
# 1048  BEHR ULTRA SCUFF DEFENSE Stain-Blocking Paint ...  recently_viewed
# 1310  BEHR ULTRA SCUFF DEFENSE Stain-Blocking Paint ...  recently_viewed
# 1444  BEHR ULTRA SCUFF DEFENSE Stain-Blocking Paint ...  recently_viewed
# 1838  BEHR ULTRA SCUFF DEFENSE Stain-Blocking Paint ...  recently_viewed
# 1938  Introducing the best of BEHR Paint. Featuring ...  recently_viewed
# 1970  Introducing the best of BEHR Paint. Featuring ...  recently_viewed

# %% [markdown]
# Now let's combine the product `title` and `description` and store it into a column called `combined`.

# %%
df['combined'] = df.title + ' ' + df.description
df
# Out:
#      product_id                                              title  \
# 0            P0  Men's 3X Large Carbon Heather Cotton/Polyester...
# 1            P1  Turmode 30 ft. RP TNC Female to RP TNC Male Ad...
# 2            P2                         Large Tapestry Bolster Bed
# 3            P3    16-Gauge-Sinks Vessel Sink in White with Faucet
# 4            P4  Men's Crazy Horse 9'' Logger Boot - Steel Toe ...
# ...         ...                                                ...
# 1995      P1995  Dotty Black and White Black and White Wallpape...
# 1996      P1996  Abrielle Brown/Light Gray 8 ft. x 10 ft. Orien...
# 1997      P1997  20 in. x 2-1/2 in. x 2-1/2 in. Polyurethane As...
# 1998      P1998  1 gal. #P120-6 Diva Glam Flat Exterior Paint &...
# 1999      P1999  Amsterdam Ivory/Terracotta 2 ft. x 8 ft. Geome...
#
#                                             description product_status  \
# 0     This heavyweight, water-repellent hooded sweat...     not_viewed
# 1     If you need more length between your existing ...     not_viewed
# 2     Polyester cover resembling rich Italian tapest...     not_viewed
# 3     It features a rectangle shape. This vessel set...     not_viewed
# 4     This 9 in. black full grain leather logger boo...     not_viewed
# ...                                                 ...            ...
# 1995  With a stylish monochrome look, this dotty wal...     not_viewed
# 1996  The Abrielle collection features a stunning as...     not_viewed
# 1997  With Fypon balustrade systems, you can transfo...     not_viewed
# 1998  BEHR PREMIUM PLUS Exterior Paint & Primer is a...     not_viewed
# 1999  A refreshing take on innovative designs, Safav...     not_viewed
#
#                                                combined
# 0     Men's 3X Large Carbon Heather Cotton/Polyester...
# 1     Turmode 30 ft. RP TNC Female to RP TNC Male Ad...
# 2     Large Tapestry Bolster Bed Polyester cover res...
# 3     16-Gauge-Sinks Vessel Sink in White with Fauce...
# 4     Men's Crazy Horse 9'' Logger Boot - Steel Toe ...
# ...                                                 ...
# 1995  Dotty Black and White Black and White Wallpape...
# 1996  Abrielle Brown/Light Gray 8 ft. x 10 ft. Orien...
# 1997  20 in. x 2-1/2 in. x 2-1/2 in. Polyurethane As...
# 1998  1 gal. #P120-6 Diva Glam Flat Exterior Paint &...
# 1999  Amsterdam Ivory/Terracotta 2 ft. x 8 ft. Geome...
#
# [2000 rows x 5 columns]

# %% [markdown]
# ### Task 3 - Text embedding and visualization

# %% [markdown]
# Creating the text embedding vectors

# %%
response = client.embeddings.create(
    input = df.combined.to_list(),
    model = 'text-embedding-3-small',
    dimensions = 512
)
vectors = [d.embedding for d in response.data]
df['text_embeddings']= vectors
df
# Out:
#      product_id                                              title  \
# 0            P0  Men's 3X Large Carbon Heather Cotton/Polyester...
# 1            P1  Turmode 30 ft. RP TNC Female to RP TNC Male Ad...
# 2            P2                         Large Tapestry Bolster Bed
# 3            P3    16-Gauge-Sinks Vessel Sink in White with Faucet
# 4            P4  Men's Crazy Horse 9'' Logger Boot - Steel Toe ...
# ...         ...                                                ...
# 1995      P1995  Dotty Black and White Black and White Wallpape...
# 1996      P1996  Abrielle Brown/Light Gray 8 ft. x 10 ft. Orien...
# 1997      P1997  20 in. x 2-1/2 in. x 2-1/2 in. Polyurethane As...
# 1998      P1998  1 gal. #P120-6 Diva Glam Flat Exterior Paint &...
# 1999      P1999  Amsterdam Ivory/Terracotta 2 ft. x 8 ft. Geome...
#
#                                             description product_status  \
# 0     This heavyweight, water-repellent hooded sweat...     not_viewed
# 1     If you need more length between your existing ...     not_viewed
# 2     Polyester cover resembling rich Italian tapest...     not_viewed
# 3     It features a rectangle shape. This vessel set...     not_viewed
# 4     This 9 in. black full grain leather logger boo...     not_viewed
# ...                                                 ...            ...
# 1995  With a stylish monochrome look, this dotty wal...     not_viewed
# 1996  The Abrielle collection features a stunning as...     not_viewed
# 1997  With Fypon balustrade systems, you can transfo...     not_viewed
# 1998  BEHR PREMIUM PLUS Exterior Paint & Primer is a...     not_viewed
# 1999  A refreshing take on innovative designs, Safav...     not_viewed
#
#                                                combined  \
# 0     Men's 3X Large Carbon Heather Cotton/Polyester...
# 1     Turmode 30 ft. RP TNC Female to RP TNC Male Ad...
# 2     Large Tapestry Bolster Bed Polyester cover res...
# 3     16-Gauge-Sinks Vessel Sink in White with Fauce...
# 4     Men's Crazy Horse 9'' Logger Boot - Steel Toe ...
# ...                                                 ...
# 1995  Dotty Black and White Black and White Wallpape...
# 1996  Abrielle Brown/Light Gray 8 ft. x 10 ft. Orien...
# 1997  20 in. x 2-1/2 in. x 2-1/2 in. Polyurethane As...
# 1998  1 gal. #P120-6 Diva Glam Flat Exterior Paint &...
# 1999  Amsterdam Ivory/Terracotta 2 ft. x 8 ft. Geome...
#
#                                         text_embeddings
# 0     [0.042664770036935806, 0.02092622220516205, -0...
# 1     [0.04413316026329994, 0.009090634062886238, 0....
# 2     [0.042361605912446976, -0.06515178084373474, 0...
# 3     [-0.049733716994524, -0.011679209768772125, 0....
# 4     [0.026085881516337395, 0.048493191599845886, -...
# ...                                                 ...
# 1995  [0.09004916995763779, -0.055176541209220886, -...
# 1996  [0.013627329841256142, -0.04656423255801201, 0...
# 1997  [-0.02963854931294918, -0.009340153075754642, ...
# 1998  [-0.01301631424576044, -0.009222120977938175, ...
# 1999  [-0.007157654967159033, -0.015520446933805943,...
#
# [2000 rows x 6 columns]

# %% [markdown]
# > We know that each vector has 512 dimensions. In order to be able to visualize the vectors in a scatter plot, we need to use Principal Component Analysis (PCA) to reduce the dimension from 512 to 2.

# %%
pca = PCA(2)
vector_2d = pca.fit_transform(df.text_embeddings.to_list())
df['pc1'] = vector_2d[:,0]
df['pc2'] = vector_2d[:,1]
df
# Out:
#      product_id                                              title  \
# 0            P0  Men's 3X Large Carbon Heather Cotton/Polyester...
# 1            P1  Turmode 30 ft. RP TNC Female to RP TNC Male Ad...
# 2            P2                         Large Tapestry Bolster Bed
# 3            P3    16-Gauge-Sinks Vessel Sink in White with Faucet
# 4            P4  Men's Crazy Horse 9'' Logger Boot - Steel Toe ...
# ...         ...                                                ...
# 1995      P1995  Dotty Black and White Black and White Wallpape...
# 1996      P1996  Abrielle Brown/Light Gray 8 ft. x 10 ft. Orien...
# 1997      P1997  20 in. x 2-1/2 in. x 2-1/2 in. Polyurethane As...
# 1998      P1998  1 gal. #P120-6 Diva Glam Flat Exterior Paint &...
# 1999      P1999  Amsterdam Ivory/Terracotta 2 ft. x 8 ft. Geome...
#
#                                             description product_status  \
# 0     This heavyweight, water-repellent hooded sweat...     not_viewed
# 1     If you need more length between your existing ...     not_viewed
# 2     Polyester cover resembling rich Italian tapest...     not_viewed
# 3     It features a rectangle shape. This vessel set...     not_viewed
# 4     This 9 in. black full grain leather logger boo...     not_viewed
# ...                                                 ...            ...
# 1995  With a stylish monochrome look, this dotty wal...     not_viewed
# 1996  The Abrielle collection features a stunning as...     not_viewed
# 1997  With Fypon balustrade systems, you can transfo...     not_viewed
# 1998  BEHR PREMIUM PLUS Exterior Paint & Primer is a...     not_viewed
# 1999  A refreshing take on innovative designs, Safav...     not_viewed
#
#                                                combined  \
# 0     Men's 3X Large Carbon Heather Cotton/Polyester...
# 1     Turmode 30 ft. RP TNC Female to RP TNC Male Ad...
# 2     Large Tapestry Bolster Bed Polyester cover res...
# 3     16-Gauge-Sinks Vessel Sink in White with Fauce...
# 4     Men's Crazy Horse 9'' Logger Boot - Steel Toe ...
# ...                                                 ...
# 1995  Dotty Black and White Black and White Wallpape...
# 1996  Abrielle Brown/Light Gray 8 ft. x 10 ft. Orien...
# 1997  20 in. x 2-1/2 in. x 2-1/2 in. Polyurethane As...
# 1998  1 gal. #P120-6 Diva Glam Flat Exterior Paint &...
# 1999  Amsterdam Ivory/Terracotta 2 ft. x 8 ft. Geome...
#
#                                         text_embeddings       pc1       pc2
# 0     [0.042664770036935806, 0.02092622220516205, -0... -0.000228  0.066309
# 1     [0.04413316026329994, 0.009090634062886238, 0.... -0.363652  0.235434
# 2     [0.042361605912446976, -0.06515178084373474, 0... -0.209285 -0.214405
# 3     [-0.049733716994524, -0.011679209768772125, 0.... -0.179814  0.039086
# 4     [0.026085881516337395, 0.048493191599845886, -... -0.212957  0.143710
# ...                                                 ...       ...       ...
# 1995  [0.09004916995763779, -0.055176541209220886, -... -0.038057 -0.195877
# 1996  [0.013627329841256142, -0.04656423255801201, 0... -0.245514 -0.483502
# 1997  [-0.02963854931294918, -0.009340153075754642, ... -0.081740  0.105612
# 1998  [-0.01301631424576044, -0.009222120977938175, ...  0.502578  0.003993
# 1999  [-0.007157654967159033, -0.015520446933805943,... -0.270773 -0.429852
#
# [2000 rows x 8 columns]

# %% [markdown]
# Now that we have the text embedding vectors in two dimensions, we can use them to create a 2D plot.

# %%
px.scatter(df, x='pc1', y='pc2', color= 'product_status')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ccac45bd-35bc-4565-a467-b053084fba3d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ccac45bd-35bc-4565-a467-b053084fba3d")) {                    Plotly.newPlot(                        "ccac45bd-35bc-4565-a467-b053084fba3d",                        [{"hovertemplate":"product_status=not_viewed\u003cbr\u003epc1=%{x}\u003cbr\u003epc2=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"not_viewed","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"not_viewed","showlegend":true,"x":[-0.00022844685403640148,-0.3636516858154277,-0.20928466386118844,-0.17981449916201905,-0.21295745815715708,-0.19027715389995406,0.4805744177411922,-0.10993794566243922,-0.29416683010906763,-0.3001536402724708,-0.01578466772518686,0.5075851900576229,-0.2794217427951035,-0.18937416995909634,-0.16271842708543544,-0.15421608806454432,0.4804755398612645,-0.18395394901670667,0.49386656458962724,-0.0799958250567638,-0.15873379073184143,-0.2563220229604456,-0.03462005592132451,-0.13714089467507395,0.34406167121194825,-0.20857617071615078,0.44619506128657,-0.16106534367590258,-0.16750434129210837,-0.0720766502624594,0.3731641858623448,-0.12655842505199158,-0.20948895563077385,0.5138190374298195,-0.061268071451621636,-0.18978017526675467,-0.11758016553525906,-0.11667928130987763,-0.07383366936645629,-0.048242743552434006,0.5066538817746292,-0.1067234465112516,-0.031053175462442267,-0.07024296082820108,-0.1848937812023972,-0.18233619957022362,-0.25267481995900876,-0.11175917455559421,-0.1970275453647141,-0.19113381311141894,0.5178280899256122,-0.09531801752288648,-0.22740894328804762,0.4232821425309936,-0.10968066103212586,-0.2808102266074209,-0.14933782741081117,-0.17262895677850093,0.4618787823015235,0.4626917638989315,-0.2112800019769753,-0.07876113781591308,-0.18641343728517884,0.477335003070596,-0.23802905552675577,0.5223409410306118,-0.19420918053097325,-0.21579250033119587,-0.18052253166336837,0.3972386257645579,-0.1855175998004032,-0.31827117951473755,0.49307711779605773,-0.0857696638982783,-0.247099905373338,-0.000816268326017696,-0.21733192035832805,-0.2114730109520724,-0.23764430773520134,-0.2019900611855906,0.3705332587043554,0.4542046843441875,-0.05073661763291827,-0.1797228915776446,-0.1271701946923223,-0.17567548509169204,-0.22042937426603623,-0.25898542413149,0.378611467496077,0.414565216432041,0.35370370549499325,-0.1263017370351827,-0.058351476994066044,0.5002183048329265,-0.09949032105953004,-0.16523987311456034,-0.29910021437572104,-0.21897646528404427,0.4362324836465822,-0.20408843301638205,-0.13937005382867157,-0.2735692716776141,-0.23282684110437912,-0.1719842786404697,-0.22767557210391504,0.514090275384033,0.29005632122789093,-0.10674593195206314,-0.2146384847238015,-0.13082769006416006,-0.1886030316379304,0.4933115369644669,-0.03597863142447317,0.4992671734039206,-0.07851068208368352,-0.11034293983436086,-0.12903085405787101,0.4964710132725225,0.484015515652843,-0.2540334781062393,-0.13225384719256955,-0.22742676185590383,0.5088552386946789,-0.07067778767525243,-0.14941028745906795,0.4384813119011351,-0.2203464554560591,-0.11398397804816014,-0.08265725288009783,0.37692273201678933,-0.2577051103083186,0.4511541581948309,0.5553645962995868,0.47121377864637193,-0.22147559198989067,0.39176349970712804,-0.18593611836609142,-0.0758724101226227,-0.1328871816299266,-0.31321048317241984,-0.1713484769612391,-0.130337549930918,0.4459475427338906,-0.1051804722458111,-0.19097239170934605,-0.22460192675337629,-0.06636463145308648,-0.20748283900247227,-0.25342625934928714,-0.27798413096800734,-0.27653089207201564,-0.2878212194381413,-0.08711901703166995,-0.21282257276078861,0.3744064136692878,-0.07921713484530218,0.5 ...

# %% [markdown]
# ### Task 4 - Find similar products

# %%
df.head()
# Out:
#   product_id                                              title  \
# 0         P0  Men's 3X Large Carbon Heather Cotton/Polyester...
# 1         P1  Turmode 30 ft. RP TNC Female to RP TNC Male Ad...
# 2         P2                         Large Tapestry Bolster Bed
# 3         P3    16-Gauge-Sinks Vessel Sink in White with Faucet
# 4         P4  Men's Crazy Horse 9'' Logger Boot - Steel Toe ...
#
#                                          description product_status  \
# 0  This heavyweight, water-repellent hooded sweat...     not_viewed
# 1  If you need more length between your existing ...     not_viewed
# 2  Polyester cover resembling rich Italian tapest...     not_viewed
# 3  It features a rectangle shape. This vessel set...     not_viewed
# 4  This 9 in. black full grain leather logger boo...     not_viewed
#
#                                             combined  \
# 0  Men's 3X Large Carbon Heather Cotton/Polyester...
# 1  Turmode 30 ft. RP TNC Female to RP TNC Male Ad...
# 2  Large Tapestry Bolster Bed Polyester cover res...
# 3  16-Gauge-Sinks Vessel Sink in White with Fauce...
# 4  Men's Crazy Horse 9'' Logger Boot - Steel Toe ...
#
#                                      text_embeddings       pc1       pc2
# 0  [0.042664770036935806, 0.02092622220516205, -0... -0.000228  0.066309
# 1  [0.04413316026329994, 0.009090634062886238, 0.... -0.363652  0.235434
# 2  [0.042361605912446976, -0.06515178084373474, 0... -0.209285 -0.214405
# 3  [-0.049733716994524, -0.011679209768772125, 0.... -0.179814  0.039086
# 4  [0.026085881516337395, 0.048493191599845886, -... -0.212957  0.143710

# %% [markdown]
# Get the data related to `recently_viewed` and `not_viewed` products

# %%
df_recently_viewed = df[df.product_status=='recently_viewed']
df_not_viewed = df[df.product_status=='not_viewed']
df_recently_viewed
# Out:
#      product_id                                              title  \
# 1017      P1017  1 qt. #660D-7 Blackberry Farm Satin Enamel Int...
# 1044      P1044  1 qt. #M360-4 Marjoram One-Coat Hide Eggshell ...
# 1048      P1048  5 gal. #640C-1 Hosta Flower Extra Durable Sati...
# 1310      P1310  5 gal. #180A-2 Romantic Morn Extra Durable Sem...
# 1444      P1444  5 gal. #PPU12-17 Cameroon Green Extra Durable ...
# 1838      P1838  5 gal. #N340-2 Dune Grass Extra Durable Satin ...
# 1938      P1938  1 gal. #HDC-SP16-10 Japanese Rose Garden Semi-...
# 1970      P1970  8 oz. #510C-3 Rivers Edge Semi-Gloss Enamel St...
#
#                                             description   product_status  \
# 1017  Love your space like never before with the hig...  recently_viewed
# 1044  Introducing the best of BEHR Paint. Featuring ...  recently_viewed
# 1048  BEHR ULTRA SCUFF DEFENSE Stain-Blocking Paint ...  recently_viewed
# 1310  BEHR ULTRA SCUFF DEFENSE Stain-Blocking Paint ...  recently_viewed
# 1444  BEHR ULTRA SCUFF DEFENSE Stain-Blocking Paint ...  recently_viewed
# 1838  BEHR ULTRA SCUFF DEFENSE Stain-Blocking Paint ...  recently_viewed
# 1938  Introducing the best of BEHR Paint. Featuring ...  recently_viewed
# 1970  Introducing the best of BEHR Paint. Featuring ...  recently_viewed
#
#                                                combined  \
# 1017  1 qt. #660D-7 Blackberry Farm Satin Enamel Int...
# 1044  1 qt. #M360-4 Marjoram One-Coat Hide Eggshell ...
# 1048  5 gal. #640C-1 Hosta Flower Extra Durable Sati...
# 1310  5 gal. #180A-2 Romantic Morn Extra Durable Sem...
# 1444  5 gal. #PPU12-17 Cameroon Green Extra Durable ...
# 1838  5 gal. #N340-2 Dune Grass Extra Durable Satin ...
# 1938  1 gal. #HDC-SP16-10 Japanese Rose Garden Semi-...
# 1970  8 oz. #510C-3 Rivers Edge Semi-Gloss Enamel St...
#
#                                         text_embeddings       pc1       pc2
# 1017  [0.05918155610561371, -0.02796226739883423, 0....  0.470231 -0.057174
# 1044  [0.02989116683602333, -0.02771798148751259, 0....  0.470721 -0.046263
# 1048  [0.0008034154889173806, -0.027133531868457794,...  0.457054 -0.029320
# 1310  [0.00219642068259418, -0.006548991892486811, 0...  0.466699 -0.048816
# 1444  [0.05091223120689392, -0.016536731272935867, 0...  0.464626 -0.051651
# 1838  [0.00441074650734663, -0.014054427854716778, 0...  0.459178 -0.051003
# 1938  [0.006750619970262051, -0.060344669967889786, ...  0.469535 -0.050441
# 1970  [0.03179488703608513, -0.06424853950738907, 0....  0.471999 -0.045673

# %% [markdown]
# Convert the embedding vectors to Numpy arrays

# %%
vectors_recently_viewed = np.array(df_recently_viewed.text_embeddings.to_list())
vectors_not_viewed = np.array(df_not_viewed.text_embeddings.to_list())
vectors_recently_viewed
# Out:
# array([[ 0.05918156, -0.02796227,  0.05370384, ...,  0.03199653,
#         -0.0369931 ,  0.02376145],
#        [ 0.02989117, -0.02771798,  0.05270961, ...,  0.01695084,
#         -0.08368737,  0.05685841],
#        [ 0.00080342, -0.02713353,  0.04528342, ..., -0.00164107,
#         -0.04122982,  0.04933701],
#        ...,
#        [ 0.00441075, -0.01405443,  0.05610869, ..., -0.00937568,
#         -0.03830218,  0.05352857],
#        [ 0.00675062, -0.06034467,  0.04007325, ..., -0.02216943,
#         -0.0787768 ,  0.08100744],
#        [ 0.03179489, -0.06424854,  0.01230332, ..., -0.00732387,
#         -0.02857859,  0.0742462 ]])

# %% [markdown]
# Find the similarity between each viewed product and all the unviewed products.

# %%
similarity_matrix = cosine_similarity(vectors_recently_viewed, vectors_not_viewed)
top_ids= []
for row in similarity_matrix:
  top_id = np.argmax(row)
  top_ids.append(top_id)

most_similar_product_ids=list(df_not_viewed.iloc[top_ids].product_id)
most_similar_product_ids
# Out:
# ['P854', 'P1061', 'P1705', 'P733', 'P1327', 'P1705', 'P1501', 'P314']

# %% [markdown]
# ### Task 5 - Recommend products based on the searched products

# %% [markdown]
# Let's update the status of the top similar products to `recommended`.

# %%
df.loc[df.product_id.isin(most_similar_product_ids),'product_status'] = 'recommended'
df[df.product_status=='recommended']
# Out:
#      product_id                                              title  \
# 314        P314  8 oz. #230F-7 Florence Brown Semi-Gloss Enamel...
# 733        P733  5 gal. #N440-1 Streetwise Extra Durable Semi-G...
# 854        P854  1 qt. #N460-1 Evening White Satin Enamel Inter...
# 1061      P1061  1 gal. #MQ1-28 Orange Flambe One-Coat Hide Egg...
# 1327      P1327  5 gal. #MQ4-44 Green Dynasty Extra Durable Egg...
# 1501      P1501  1 gal. #S-H-620 Midnight Sky Semi-Gloss Enamel...
# 1705      P1705  5 gal. #310D-4 Gold Buff Extra Durable Satin E...
#
#                                             description product_status  \
# 314   Introducing the best of BEHR Paint. Featuring ...    recommended
# 733   BEHR ULTRA SCUFF DEFENSE Stain-Blocking Paint ...    recommended
# 854   Love your space like never before with the hig...    recommended
# 1061  Introducing the best of BEHR Paint. Featuring ...    recommended
# 1327  BEHR ULTRA SCUFF DEFENSE Stain-Blocking Paint ...    recommended
# 1501  Introducing the best of BEHR Paint. Featuring ...    recommended
# 1705  BEHR ULTRA SCUFF DEFENSE Stain-Blocking Paint ...    recommended
#
#                                                combined  \
# 314   8 oz. #230F-7 Florence Brown Semi-Gloss Enamel...
# 733   5 gal. #N440-1 Streetwise Extra Durable Semi-G...
# 854   1 qt. #N460-1 Evening White Satin Enamel Inter...
# 1061  1 gal. #MQ1-28 Orange Flambe One-Coat Hide Egg...
# 1327  5 gal. #MQ4-44 Green Dynasty Extra Durable Egg...
# 1501  1 gal. #S-H-620 Midnight Sky Semi-Gloss Enamel...
# 1705  5 gal. #310D-4 Gold Buff Extra Durable Satin E...
#
#                                         text_embeddings       pc1       pc2
# 314   [-0.003989859018474817, -0.060487765818834305,...  0.493714 -0.052179
# 733   [0.009646818973124027, -0.017993971705436707, ...  0.459837 -0.004503
# 854   [0.04255978390574455, -0.019562887027859688, 0...  0.491744 -0.053056
# 1061  [0.01663183607161045, -0.026091130450367928, 0...  0.496061 -0.063851
# 1327  [0.0505719892680645, -0.01987646520137787, 0.0...  0.468602 -0.063277
# 1501  [0.020269175991415977, -0.041455335915088654, ...  0.492105 -0.039515
# 1705  [-0.002052590949460864, -0.012245520949363708,...  0.460866 -0.032162

# %% [markdown]
# Let's visualize the recommended products.

# %%
px.scatter(df, x='pc1', y='pc2', color= 'product_status', hover_data='title')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1287834b-3d60-4fec-b6ae-4ff879fdf919" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1287834b-3d60-4fec-b6ae-4ff879fdf919")) {                    Plotly.newPlot(                        "1287834b-3d60-4fec-b6ae-4ff879fdf919",                        [{"customdata":[["Men's 3X Large Carbon Heather Cotton\u002fPolyester Rain Defender Paxton Heavyweight Hooded Zip-Front Sweatshirt"],["Turmode 30 ft. RP TNC Female to RP TNC Male Adapter Cable"],["Large Tapestry Bolster Bed"],["16-Gauge-Sinks Vessel Sink in White with Faucet"],["Men's Crazy Horse 9'' Logger Boot - Steel Toe - Black Size 10.5(W)"],["Mariana 6 ft. Multi-Color 3-Panel Screen Divider"],["5 gal. #650C-2 Powdery Mist Semi-Gloss Interior Paint"],["7\u002f8 in. x 4-1\u002f2 in. x 0.045 in. Metal and Stainless Cutting Wheel (50-Pack)"],["Ring Gold Bar Cart"],["Traditional Silver Wooden Vanity Table"],["15 in. x 59 in. Open Louvered Polypropylene Shutters Pair in Peppercorn"],["1 qt. #350F-7 Wild Mushroom Semi-Gloss Enamel Low Odor Interior Paint & Primer"],["Anthracite Cordless Light Filtering Fabric Cellular Shade 9\u002f16 in. Single Cell 46.5 in. W x 72 in. L"],["SlimGrip 78-Inch Black Aluminum Truck Running Boards, Select Ram 1500 Quad Cab"],["6 in. x 28 in. x 28 in. Douglas Fir Balboa Arts and Crafts Rough Sawn Outlooker"],["Espresso Cordless Room Darkening 2.5 in. Premium Faux Wood Blind for Window - 35.5 in. W x 48 in. L"],["5 gal. #BL-W10 Maui Mist Semi-Gloss Enamel Low Odor Interior Paint & Primer"],["Eleyn 26 in. Indoor Chrome Remote Controlled Fandelier with Light Kit"],["1 qt. #M400-5 Baby Spinach Satin Enamel Exterior Paint & Primer"],["10 in. x 4 in. x 16 ft. 3-Sided (U-Beam) Pecky Cypress Burnished Honey Dew Faux Wood Ceiling Beam"],["5-Drawer Sandra Cream Storage Chest"],["Whimsicle Blue Multicolor 2 ft. x 8 ft. Geometric Contemporary Runner Rug"],["PrimeChime Plus 2 Video Compatible Wired Door Bell Chime Kit with White Stucco Button"],["Radiator"],["5-gal. #HDGO64U Classic Ivory Semi-Gloss Latex Exterior Paint"],["58.25 in. x 67 in. Frameless Pivot Wall Hinged Shower Bath Door"],["5 gal. #W-B-320 White Corn Extra Durable Satin Enamel Interior Paint & Primer"],["18 oz. Clear Hand Blown Recycled Glass Water Goblet (Set of 6)"],["ONE+ 18V 6 Gal. Cordless Wet\u002fDry Vacuum (Tool Only) with Hose, Crevice Tool, Floor Nozzle and Extension Wand"],["Ascension by Cap Pannell Country Poster and Print 54 in. x 54 in."],["1 qt. Bermuda Sand PPG1074-3 Flat Interior Latex Paint"],["3\u002f4 in. x 5 in. x 10 in. PVC Standard Foster Plinth Block Moulding with Square Edge"],["12 in. Balsam Fir Classic Christmas Fresh Kissing Ball Arrangement : Multiple Ship Weeks Available"],["1 gal. #N210-6 Swiss Brown Eggshell Enamel Interior Paint & Primer"],["Double Strawberry' Framed Food Art Print 19 in. x 13 in."],["Hercules Lesley Series Contemporary White Leather Chair with Encasing Frame"],["6 in. x 4 in. x 9 in. Alder Arts and Crafts Corbel"],["New White Power Nozzle Designed to Fit All Brands of Vacuums"],["Designer Series Melvern Storm Gray 0.75 in. x 30 in. x 12 in. Melvern Decorative End Panel"],["Quartz Yellow Paper Strippable Roll (Covers 57 sq. ft.)"],["1 gal. #110B-6 Cran Brook Semi-Gloss Enamel Low Odor Interior Paint & Primer"],["8 in. x 8 in. x 5 ft. Rough Cedar Faux Wood Beam Fireplace Mantel, Burnished Pine"],["24 in. x 30 in. \"Bright Colored Painting Girls Reading at the Beach\" by Patti Mollica Framed Wall Art"],["24 in. x 24 in. x 1\u002f8 in. Thick Acrylic Orange 2119 Sheet"],["Mini 1-Light Antique Bronze Indoor\u002fOutdoor Lamp\u002fLantern Wall Mount\u002fWall Sconce with Clear Cylindrical Glass"],["Belmore 30.25 in. to 31.25 in. x 72 in. Frameless Hi ...
